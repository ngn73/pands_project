# %% [markdown]
# # <font color='sky blue'>Analysis Summary of attribute petal.width</font>
# These are the analysis insights into feature selected on Application form.
#   DateFile : notebooks\Analysis_ 152729.ipynb
#   Attribute : petal.width
# *Notebook autogenerated with python code*

# %% [markdown]
# **Feature : <font color='crimson'>petal.width</font>**
# Count : 150
# NAN Count : 0
# Mean : 1.199
# Median : 1.300
# Standard Deviation : 0.762
# Variance : 0.581
# Minimum : 0.100
# Maximum : 2.500
# Skewness : -0.103
# Kurtosis  : -1.341
# Interquartile Range  75th percentile(Q3) : 0.300
# Interquartile Range  25th percentile(Q1) : 1.800

# %% [markdown]
# ![Plot](data:image/png;base64,...)

# %% [markdown]
# ![Plot](data:image/png;base64,...)
