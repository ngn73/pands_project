# %% [markdown]
# # <font color='sky blue'>Analysis Summary of attribute petal.length</font>
# These are the analysis insights into feature selected on Application form.
#   DateFile : notebooks\Analysis_ 529576.ipynb
#   Attribute : petal.length
# *Notebook autogenerated with python code*

# %% [markdown]
# ![Plot](data:image/png;base64,...)
