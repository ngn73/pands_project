# %% [markdown]
# # <font color='sky blue'>Analysis Summary of attribute BillDepth</font>
# These are the analysis insights into feature selected on Application form.
#   DateFile : notebooks\Analysis_ 92978.ipynb
#   Attribute : BillDepth
# *Notebook autogenerated with python code*

# %% [markdown]
# ![Plot](data:image/png;base64,...)
