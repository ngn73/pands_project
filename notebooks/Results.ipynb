# %% [markdown]
# # <font color='sky blue'>Statistical Summary of dataset</font>
# These are the statistical insights into each feature of dataset.

# %% [markdown]
# **Feature : <font color='crimson'>sepal.length</font>**
# Mean : 5.843
# Median : 5.800
# Standard Deviation : 0.825
# Variance : 0.681
# Minimum : 4.300
# Maximum : 7.900
# Skewness : 0.312
# Kurtosis  : -0.574
# Interquartile Range  75th percentile(Q3) : 5.100
# Interquartile Range  25th percentile(Q1) : 6.400
#
# **Feature : <font color='crimson'>sepal.width</font>**
# Mean : 3.057
# Median : 3.000
# Standard Deviation : 0.434
# Variance : 0.189
# Minimum : 2.000
# Maximum : 4.400
# Skewness : 0.316
# Kurtosis  : 0.181
# Interquartile Range  75th percentile(Q3) : 2.800
# Interquartile Range  25th percentile(Q1) : 3.300
#
# **Feature : <font color='crimson'>petal.length</font>**
# Mean : 3.758
# Median : 4.350
# Standard Deviation : 1.759
# Variance : 3.096
# Minimum : 1.000
# Maximum : 6.900
# Skewness : -0.272
# Kurtosis  : -1.396
# Interquartile Range  75th percentile(Q3) : 1.600
# Interquartile Range  25th percentile(Q1) : 5.100
#
# **Feature : <font color='crimson'>petal.width</font>**
# Mean : 1.199
# Median : 1.300
# Standard Deviation : 0.760
# Variance : 0.577
# Minimum : 0.100
# Maximum : 2.500
# Skewness : -0.102
# Kurtosis  : -1.336
# Interquartile Range  75th percentile(Q3) : 0.300
# Interquartile Range  25th percentile(Q1) : 1.800
