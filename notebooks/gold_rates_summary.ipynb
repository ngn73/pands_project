# %% [markdown]
# # <font color='sky blue'>Statistical Summary of dataset</font>
# These are the statistical insights into each feature of dataset.

# %% [markdown]
# **Feature : <font color='crimson'>USD</font>**
# Mean : 750.834
# Median : 424.550
# Standard Deviation : 506.050
# Variance : 256086.678
# Minimum : 252.800
# Maximum : 2067.150
# Skewness : 0.784
# Kurtosis  : -0.878
# Interquartile Range  75th percentile(Q3) : 353.800
# Interquartile Range  25th percentile(Q1) : 1232.250
#
# **Feature : <font color='crimson'>EUR</font>**
# Mean : 620.479
# Median : 361.140
# Standard Deviation : 410.456
# Variance : 168474.059
# Minimum : 222.200
# Maximum : 1745.460
# Skewness : 0.899
# Kurtosis  : -0.648
# Interquartile Range  75th percentile(Q3) : 305.120
# Interquartile Range  25th percentile(Q1) : 1013.090
#
# **Feature : <font color='crimson'>GBP</font>**
# Mean : 496.608
# Median : 259.100
# Standard Deviation : 371.541
# Variance : 138042.739
# Minimum : 157.150
# Maximum : 1572.810
# Skewness : 0.946
# Kurtosis  : -0.515
# Interquartile Range  75th percentile(Q3) : 219.310
# Interquartile Range  25th percentile(Q1) : 816.530
#
# **Feature : <font color='crimson'>INR</font>**
# Mean : 39071.462
# Median : 16913.480
# Standard Deviation : 38031.092
# Variance : 1446363944.057
# Minimum : 3687.170
# Maximum : 154901.870
# Skewness : 1.014
# Kurtosis  : -0.172
# Interquartile Range  75th percentile(Q3) : 11584.750
# Interquartile Range  25th percentile(Q1) : 75724.770
#
# **Feature : <font color='crimson'>AED</font>**
# Mean : 2757.625
# Median : 1559.510
# Standard Deviation : 1858.890
# Variance : 3455470.859
# Minimum : 928.530
# Maximum : 7592.950
# Skewness : 0.784
# Kurtosis  : -0.878
# Interquartile Range  75th percentile(Q3) : 1297.540
# Interquartile Range  25th percentile(Q1) : 4526.240
#
# **Feature : <font color='crimson'>CNY</font>**
# Mean : 4962.734
# Median : nan
# Standard Deviation : 3358.832
# Variance : 11281755.321
# Minimum : 809.630
# Maximum : 14355.530
# Skewness : nan
# Kurtosis  : nan
# Interquartile Range  75th percentile(Q3) : nan
# Interquartile Range  25th percentile(Q1) : nan
